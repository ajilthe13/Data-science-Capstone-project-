# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Solving this problem will help you to gain a basic understanding of the HR industry and also how analytics and data science are applied in practice in this domain.
#
# A brief understanding of the HR industry
#
# Human resources (HR) is the division of an organization that is responsible for finding, screening, recruiting, and training job applicants, and administering employee-benefit programs.
#
# This management is the strategic approach to the efficient management of people in any organization in a way that can help their business gain a competitive advantage. It is designed to improve employee performance in service of an employer's strategic objectives.
#
# Understanding the Problem Statement
#
# In this project, you will have to put yourself in the shoes of an HR analytics expert and by leveraging the data provided, you are supposed to identify how salary is varying with respect to other considerable factors.
#
# The dataset should be divided into test and train and you would have to use the training data to build the model and thereby apply it to test data to measure the performance and robustness of the model.
#
# General steps to be followed and tentative timelines:
#
# Understand the problem statement: 1 hour
# Understand the data, make a valid business sense and write about it: 4 hours
# Data analysis and interpretations: 4 hours
# Data Cleaning and justification : 5 hours
# Feature engineering(If needed) : 4 hours
# Model building : 5 hours(Justify why are you choosing a particular technique over others)
# Cross-validation, performance check, and its explanation : 4 hours
# Rework on different models, if needed : 4 hours
# Visual interpretation : 2 hours
# Results and Recommendations: 2 hours
#
# Steps to be performed for successful completion of capstone project:
#
# Understand the data set - Feature description provided below.
# Check the number of variables that are normally distributed & explain
# Find out the correlation between variables using spearman rank correlation & explain
# Examine the relationship between categorical variables and the dependent variable & explain
# Clean and pre-process the data with other operations required, like, missing values, handling outliers, etc. as and when necessary & explain
# Apply ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable for the same & explain
# Briefly write your inference for every step, justifying the logic for the same.
#
#
# Feature Description
#
# Gender - talks of the gender - Male or female
# Business - if the person has a business or no
# Age - age of the person
# Salary - CTC of the employee
# Dependants - number of people dependant on the person
# Months - duration of the person employed with the company
# Calls - if the person has authority to make calls or not
# Type - salary settlement type
# Billing - Subscribed to billing plans or no
# Unit sales - unit sale made by the person
# Total sales - total sales made by the person
# Rating - If he has been given a rating by a superior or no
# Bonus - amount received by a person as bonus for sales
# Base pay - Base pay of the employee
# Unit price - The Unit price of a sale
# Volume - volume allotted to a person
# Opening balance - The opening balance of an employee
# Low - lowest balance allotted to a person.
# Closing Balance- The closing balance of an employee
# Education- Educational background of an employee

# %% [markdown]
# Project:

# %% [markdown]
# ### Solving this problem will help you to gain a basic understanding of the HR industry and also how analytics and data science are applied in practice in this domain.

# %% [markdown]
# - Gender - talks of the gender - Male or female
# - Business - if the person has a business or no
# - Age - age of the person
# - Salary - CTC of the employee
# - Dependants - number of people dependant on the person
# - Months - duration of the person employed with the company
# - Calls - if the person has authority to make calls or not
# - Type - salary settlement type
# - Billing - Subscribed to billing plans or no
# - Unit sales - unit sale made by the person
# - Total sales - total sales made by the person
# - Rating - If he has been given a rating by a superior or no
# - Bonus - amount received by a person as bonus for sales
# - Base pay - Base pay of the employee
# - Unit price - The Unit price of a sale
# - Volume - volume allotted to a person
# - Opening balance - The opening balance of an employee
# - Low - lowest balance allotted to a person.
# - Closing Balance- The closing balance of an employee
# - Education- Educational background of an employee

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pingouin as pg
from pingouin import ttest

# %% [markdown]
# # Reading Data set

# %%
df = pd.read_csv('New_data_Set1.csv')

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %% [markdown]
# ###### - The Dataset looks like the employees of the company containg information about the company, product and the people who work there

# %%
df.head()
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
#
#     Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2  5896.65  2358.660  294.8325        3.89  18761000            4.23
# 3  6125.12  2450.048  306.2560        4.35  66130600            4.26
# 4  6245.00  2498.000  312.2500        4.34  26868200            4.79
#
#    closingbalance   low  Unit_Sales Total_Sales  Months            Education
# ...

# %% [markdown]
# #### The Data Set Contains 5000 Rows and 20 cOlumns

# %%
df.tail()
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.isnull()
# Out:
#       Gender  Business  Dependancies  Calls   Type  Billing  Rating    Age  \
# 0      False     False         False  False  False    False   False  False
# 1      False     False         False  False  False    False   False  False
# 2      False     False         False  False  False    False   False  False
# 3      False     False         False  False  False    False   False  False
# 4      False     False         False  False  False    False   False  False
# ...      ...       ...           ...    ...    ...      ...     ...    ...
# 4995   False     False         False  False  False    False   False  False
# 4996   False     False         False  False  False    False   False  False
# 4997   False     False         False  False  False    False   False  False
# 4998   False     False         False  False  False    False   False  False
# 4999   False     False         False  False  False    False   False  False
#
#       Salary  Base_pay  Bonus  Unit_Price  Volume  openingbalance  \
# ...

# %% [markdown]
# # Finding null values

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales          8
# Months               0
# Education            0
# dtype: int64

# %%
plt.figure(figsize=(25, 5))
sns.heatmap(df.isnull(), yticklabels=False,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### AS we see there are null values present in dataset

# %% [markdown]
# # Changing Dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# #### By Comparing Datatype To dataset it conclude that (Total_sales) Showing in object Datatype

# %%
df['Total_Sales'] = pd.to_numeric(df['Total_Sales'], errors = 'coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# #### Now Total_Sales Dtype showing in float and now we good to go

# %% [markdown]
# # Removing Null Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# #### Filling The null Values with mean Values [Base pay,Opening balance, Total sales]

# %%
df['Base_pay'].mean()
# Out:
# 40046.18770678186

# %%
df["Base_pay"].fillna(value = df['Base_pay'].mean(),inplace = True)

# %%
df['openingbalance'].mean()
# Out:
# 43.92202005048581

# %%
df["openingbalance"].fillna(value = df['openingbalance'].mean(),inplace = True)

# %%
df['Total_Sales'].mean()
# Out:
# 2272.3739767255197

# %%
df["Total_Sales"].fillna(value = df['Total_Sales'].mean(),inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        5000 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  5000 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# #### as we see all values showing 5000

# %%
plt.figure(figsize=(25, 6))
sns.heatmap(df.isnull(), yticklabels=False,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### As we see There are No null values present in data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        5000 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  5000 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df.shape
# Out:
# (5000, 20)

# %% [markdown]
# # Checking No of Variables that are normally distributed

# %% [markdown]
# ### For Normally Distribution i have used all numeric variables to uderstand the distribution

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Age'],color="Indigo")
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# From above fig we can conclude that "Age" is normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Salary'],color='indigo')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %% [markdown]
# "Salary" are also normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Base_pay'],color='indigo')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Base_pay', ylabel='Density'>

# %% [markdown]
# "Base_pay" are also normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Bonus'],color='indigo')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Bonus', ylabel='Density'>

# %% [markdown]
# "Bonus" are also normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Unit_Price'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Unit_Price', ylabel='Density'>

# %% [markdown]
# "Unit_price" are not normally distributed it's values goes up from 0 to 50 and starts falling down upto 350

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Volume'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %% [markdown]
# "Volume" are not normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['openingbalance'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='openingbalance', ylabel='Density'>

# %% [markdown]
# "openingbalance" are not normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['closingbalance'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='closingbalance', ylabel='Density'>

# %% [markdown]
# "closingbalance" are not normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['low'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='low', ylabel='Density'>

# %% [markdown]
# "low" values are not normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Unit_Sales'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Unit_Sales', ylabel='Density'>

# %% [markdown]
# "Unit_Sales"  values are not normally distributed

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['Total_Sales'],color='teal')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Total_Sales', ylabel='Density'>

# %% [markdown]
# #### "Total_Sales" values are also not normally distributed

# %% [markdown]
# #### - Observation :
#
# #### [Age , Salary , Base_pay , Bonus] are normally distributed values
#
# #### [Unit_price , Volume , Openingbalance , closingbalance , Low , Unit_sales & Total_sales] are not normally distributed

# %% [markdown]
# # Corelation Matrix

# %%
df.corr(method ='spearman')
# Out:
#                 Business       Age    Salary  Base_pay     Bonus  Unit_Price  \
# Business        1.000000 -0.008435 -0.018403 -0.019262 -0.018403   -0.019480
# Age            -0.008435  1.000000  0.202282  0.192930  0.202282    0.128266
# Salary         -0.018403  0.202282  1.000000  0.994006  1.000000    0.811713
# Base_pay       -0.019262  0.192930  0.994006  1.000000  0.994006    0.808311
# Bonus          -0.018403  0.202282  1.000000  0.994006  1.000000    0.811713
# Unit_Price     -0.019480  0.128266  0.811713  0.808311  0.811713    1.000000
# Volume         -0.002192 -0.039345 -0.390488 -0.390056 -0.390488   -0.324230
# openingbalance -0.006726  0.088145  0.369333  0.361648  0.369333    0.280829
# closingbalance -0.007485  0.440989  0.346498  0.339834  0.346498    0.263699
# low            -0.018103  0.202040  0.999859  0.993859  0.999859    0.812412
# Unit_Sales     -0.018363  0.202268  0.999997  0.994002  0.999997    0.811735
# ...

# %% [markdown]
# #### Salary is our dependant variables so we will look at correlation between salary and all other variables

# %% [markdown]
# #### values near to 1 or -1  are the value of high correlation & the values 0 signifies no relation

# %% [markdown]
# #### from fig we analyse that [Base_Pay,Bonus,Unit_Price,low,Unit_Sales,Total_Sales] are highly correlate with salary

# %%
def display_correlation(df):
    r = df.corr(method="spearman")
plt.figure(figsize=(16,10))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True,cmap="YlGnBu")
plt.title("Spearman Correlation")
# Out:
# Text(0.5, 1.0, 'Spearman Correlation')

# %%
sns.pairplot(df)

# %% [markdown]
# # Categorical variables and Dependent variables(Relation)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        5000 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  5000 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# #### - From above [Gender,Dependancies,Calls,Type,Billing,ratings,& Education] are categorical variables

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Gender"],y=df["Salary"],palette='rainbow')
df["Gender"].value_counts()
# Out:
# Male      2528
# Female    2472
# Name: Gender, dtype: int64

# %% [markdown]
# Both Male and Female having same salary the salary depends upon the skills

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Dependancies"],y=df["Salary"],palette='rainbow')
df["Dependancies"].value_counts()
# Out:
# No     3524
# Yes    1476
# Name: Dependancies, dtype: int64

# %% [markdown]
# As we see there is no salary and dependicies relation

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Calls"],y=df["Salary"],palette='rainbow')
df["Calls"].value_counts()
# Out:
# Yes    4539
# No      461
# Name: Calls, dtype: int64

# %% [markdown]
# The person having authority to call having more salary

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Billing"],y=df["Salary"],palette='rainbow')
df["Billing"].value_counts()
# Out:
# Yes    2956
# No     2044
# Name: Billing, dtype: int64

# %% [markdown]
# As we see people with no billing subscription having impact on salary

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Type',y='Salary',data=df,palette='rainbow')
df["Type"].value_counts()
# Out:
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: Type, dtype: int64

# %% [markdown]
# The Salary settlement type are nearly same to all monthly, one year, and two years type

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Rating"],y=df["Salary"],palette='rainbow')
df["Rating"].value_counts()
# Out:
# No     3682
# Yes    1318
# Name: Rating, dtype: int64

# %% [markdown]
# From above the people with ratings(Good/bad) not getting impact on salary

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Education"],y=df["Salary"],palette='rainbow')
df["Education"].value_counts()
# Out:
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: Education, dtype: int64

# %% [markdown]
#  The Relation between Education and Salary are people with High school or less have a low salary and intermediate educated people also have less salary and Graduation and post gradation educated people having highest salary

# %% [markdown]
# # Cleaning and pre-processing the data

# %% [markdown]
# ### Identifing a Outliars

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   5000.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10112.342452  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33744.021630  4194.516950
# 50%       0.000000    52.000000  100579.378500  40231.751415  5028.968925
# 75%       0.000000    57.000000  116912.092475  46764.836975  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     5000.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %% [markdown]
# #### To identify a outliers there are two methods
# #### 1] Look at the difference between the mean and median (median=50%)
# #### if there is huge difference between mean and median then there is an outliers
# #### 2] we can also look at the distribution of 25%,50%,75% & max values to notice any outliers
# #### if we see any major difference between any two consecutive values that mean there is an outliers

# %% [markdown]
# ### Through Obersevation [Bonus,Unit_Price,Openingbalance,Closingbalance,& low] contains an Outliers

# %%
sns.boxplot(y="Bonus",data=df)
# Out:
# <AxesSubplot:ylabel='Bonus'>

# %%
sns.boxplot(y="Unit_Price",data=df)
# Out:
# <AxesSubplot:ylabel='Unit_Price'>

# %%
sns.boxplot(y="openingbalance",data=df)
# Out:
# <AxesSubplot:ylabel='openingbalance'>

# %%
sns.boxplot(y="closingbalance",data=df)
# Out:
# <AxesSubplot:ylabel='closingbalance'>

# %%
sns.boxplot(y="low",data=df)
# Out:
# <AxesSubplot:ylabel='low'>

# %% [markdown]
# # Treating an Outliers

# %%
sns.distplot(df['Unit_Price'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['Unit_price'] = np.log(df['Unit_Price'])
sns.distplot(df['Unit_price'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %%
sns.distplot(df['openingbalance'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['openingbalance'] = np.log(df['openingbalance'])
sns.distplot(df['openingbalance'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %%
sns.distplot(df['closingbalance'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['closingbalance'] = np.log(df['closingbalance'])
sns.distplot(df['closingbalance'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %%
sns.distplot(df['low'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['low'] = np.log(df['low'])
sns.distplot(df['low'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %%
sns.distplot(df['Total_Sales'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['Total_Sales'] = np.log(df['Total_Sales'])
sns.distplot(df['Total_Sales'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %%
sns.distplot(df['Bonus'])
plt.title = "Before Log Transform"
sns.despine()
plt.show()

df['Bonus'] = np.log(df['Bonus'])
sns.distplot(df['Bonus'])
plt.title = "After Log Transform"
sns.despine()
plt.show()

# %% [markdown]
# # Creating Dummies Variables

# %%
df.head()
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
#
#     Salary  Base_pay  ...  Unit_Price    Volume  openingbalance  \
# 0  5089.00  2035.600  ...        3.77  21226600        1.321756
# 1  5698.12  2279.248  ...        3.74  10462800        1.348073
# 2  5896.65  2358.660  ...        3.89  18761000        1.442202
# 3  6125.12  2450.048  ...        4.35  66130600        1.449269
# 4  6245.00  2498.000  ...        4.34  26868200        1.566530
#
#    closingbalance       low  Unit_Sales  Total_Sales  Months  \
# 0        1.324419  1.294727       18.25     2.933857       0
# ...

# %%
df = pd.get_dummies(df,columns = ["Gender","Type","Dependancies","Calls","Billing","Rating","Education"],drop_first = True)

# %%
df.head()
# Out:
#    Business  Age   Salary  Base_pay     Bonus  Unit_Price    Volume  \
# 0         0   18  5089.00  2035.600  5.539104        3.77  21226600
# 1         0   19  5698.12  2279.248  5.652159        3.74  10462800
# 2         0   22  5896.65  2358.660  5.686407        3.89  18761000
# 3         1   21  6125.12  2450.048  5.724421        4.35  66130600
# 4         0   23  6245.00  2498.000  5.743804        4.34  26868200
#
#    openingbalance  closingbalance       low  ...  Gender_Male  Type_One year  \
# 0        1.321756        1.324419  1.294727  ...            0              0
# 1        1.348073        1.302913  1.294727  ...            0              0
# 2        1.442202        1.456287  1.313724  ...            1              0
# 3        1.449269        1.460938  1.342865  ...            0              0
# 4        1.566530        1.483875  1.406097  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %% [markdown]
# # Applying ML algorithm

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# #### Importing Required libraries

# %%
import statsmodels.api as sn

# %%
from sklearn.linear_model import LinearRegression

# %%
X_multi = df.loc[:,df.columns!="Salary"]

# %% [markdown]
# #### We droped Salary from dataset to get Independent variables

# %%
X_multi.head()
# Out:
#    Business  Age  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0         0   18  2035.600  5.539104        3.77  21226600        1.321756
# 1         0   19  2279.248  5.652159        3.74  10462800        1.348073
# 2         0   22  2358.660  5.686407        3.89  18761000        1.442202
# 3         1   21  2450.048  5.724421        4.35  66130600        1.449269
# 4         0   23  2498.000  5.743804        4.34  26868200        1.566530
#
#    closingbalance       low  Unit_Sales  ...  Gender_Male  Type_One year  \
# 0        1.324419  1.294727       18.25  ...            0              0
# 1        1.302913  1.294727       18.40  ...            0              0
# 2        1.456287  1.313724       18.70  ...            1              0
# 3        1.460938  1.342865       18.75  ...            0              0
# 4        1.483875  1.406097       18.80  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %% [markdown]
# #### independent Variables in Dataset

# %%
y_multi = df["Salary"]

# %%
y_multi.head()
# Out:
# 0    5089.00
# 1    5698.12
# 2    5896.65
# 3    6125.12
# 4    6245.00
# Name: Salary, dtype: float64

# %% [markdown]
# #### Dependent Variables

# %% [markdown]
# #### Now we Have Dependent and Independent variables

# %% [markdown]
# #### adding Constant to independant variable

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  Business  Age  Base_pay     Bonus  Unit_Price    Volume  \
# 0    1.0         0   18  2035.600  5.539104        3.77  21226600
# 1    1.0         0   19  2279.248  5.652159        3.74  10462800
# 2    1.0         0   22  2358.660  5.686407        3.89  18761000
# 3    1.0         1   21  2450.048  5.724421        4.35  66130600
# 4    1.0         0   23  2498.000  5.743804        4.34  26868200
#
#    openingbalance  closingbalance       low  ...  Gender_Male  Type_One year  \
# 0        1.321756        1.324419  1.294727  ...            0              0
# 1        1.348073        1.302913  1.294727  ...            0              0
# 2        1.442202        1.456287  1.313724  ...            1              0
# 3        1.449269        1.460938  1.342865  ...            0              0
# 4        1.566530        1.483875  1.406097  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %% [markdown]
# #### Now to fit our model

# %%
lm_multi = sn.OLS(y_multi, X_multi_cons).fit()
# ols = Ordinary Least-Squares

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.080e+05
# Date:                Fri, 17 Dec 2021   Prob (F-statistic):               0.00
# Time:                        23:06:40   Log-Likelihood:                -42264.
# No. Observations:                5000   AIC:                         8.458e+04
# Df Residuals:                    4976   BIC:                         8.473e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### - As we see our r2 values and adjcent r2 value showing 0.998 it means our Dependent and independent variables are nicely co related

# %% [markdown]
# #### - Lower the p value the more significant the variable in determining y
# #### - As we see P Values = 0 so there is siginificant Variables having high impact on y variables

# %% [markdown]
# #### - Age, Base__pay, Bonus , closingbalance , unit_price , month , low , unit_Sales and month having the lowest p values
# #### - This variables have high impact on y variable
#  #### - So we can say that salary is depend on this variables

# %% [markdown]
# #### - Looking at Coeff Data if sign is +ve it means if we increasing independent variables then dependent variables also increasing
# #### - For Ex1: Unit_Price coeff is positive and value of coeff is 9
#  #### - if suppose i am increasing the Unit_Price by 1 my salary is going to increase by 9 units
#    #### like this you can predict the all other variables

# %% [markdown]
# # Test - Train Split

# %% [markdown]
# #### importing the function

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.loc[:,df.columns!="Salary"]

# %% [markdown]
# #### Removing salary from dataset

# %%
X.head()
# Out:
#    Business  Age  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0         0   18  2035.600  5.539104        3.77  21226600        1.321756
# 1         0   19  2279.248  5.652159        3.74  10462800        1.348073
# 2         0   22  2358.660  5.686407        3.89  18761000        1.442202
# 3         1   21  2450.048  5.724421        4.35  66130600        1.449269
# 4         0   23  2498.000  5.743804        4.34  26868200        1.566530
#
#    closingbalance       low  Unit_Sales  ...  Gender_Male  Type_One year  \
# 0        1.324419  1.294727       18.25  ...            0              0
# 1        1.302913  1.294727       18.40  ...            0              0
# 2        1.456287  1.313724       18.70  ...            1              0
# 3        1.460938  1.342865       18.75  ...            0              0
# 4        1.483875  1.406097       18.80  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %% [markdown]
# #### adding Dependent variables in y

# %%
y = df["Salary"]

# %%
y.head()
# Out:
# 0    5089.00
# 1    5698.12
# 2    5896.65
# 3    6125.12
# 4    6245.00
# Name: Salary, dtype: float64

# %% [markdown]
# #### 0,1,2,3 are index values and 5089.00 ..... values are collection values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.2, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4000, 23) (1000, 23) (4000,) (1000,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# creating predicted value of Y using test
y_test_a = lm_a.predict(X_test)

# %%
# creating predicted value of X using train
y_train_a = lm_a.predict(X_train)

# %% [markdown]
# #### To check the r2 values for train - test data we import a another function

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_test_a)
# y_test is a original value & y_test_a is a predicted value of y variable
# Out:
# 0.9965706869892961

# %%
r2_score(y_train, y_train_a)
# Out:
# 0.9981373098888996

# %% [markdown]
# # Running Ridge

# %%
from sklearn import preprocessing

# %% [markdown]
# #### creating standard Scaler to trainsform x train & x test data

# %% [raw]
# Creating Scaler object to store Scaling info

# %% [markdown]
# #### Fitting X_train into scaler

# %%
scaler = preprocessing.StandardScaler().fit(X_train)

# %% [markdown]
# #### transforming X_train and X_test into X_train & X_test scale

# %%
X_train_s = scaler.transform(X_train)

# %%
X_test_s = scaler.transform(X_test)

# %% [markdown]
# #### Importing library

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# #### creating a ridge object using lambda=0.5

# %%
lm_r = Ridge(alpha = 0.5)

# %% [markdown]
# #### Fitting the model

# %%
lm_r.fit(X_train_s,y_train)
# Out:
# Ridge(alpha=0.5)

# %% [markdown]
# #### Finding r2 value on test data

# %%
r2_score(y_test, lm_r.predict(X_test_s))
# Out:
# 0.9965777319212379

# %% [markdown]
# #### r2 values lies between 0 to 1

# %% [raw]
# 1 stands for perfect fit i.e we are able to justify all the variations in y vaiable using our model
# 0 stands for not fit i.e we are not able to identify any deviation in y using our model

# %% [raw]
# r2 values lies between 0.4 to 0.8 for good models & 0.8 and above for excellient model

# %% [markdown]
# #### for trying out multiple values of hyper parameters we are importing validation_curve

# %%
from sklearn.model_selection import validation_curve

# %%
validation_curve?

# %% [markdown]
# #### creating an arrays of lambda values we are using parram_range variable

# %%
param_range = np.logspace(-2,8,100)
param_range
# Here we created a 100 values from -2 to 8 by using log space
#this logspace values creates a 100 values between 10*-2 to 10*8
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %% [markdown]
# #### using this values as a values of our lambda for our model and then select the best lambda value out of this

# %%
train_score, test_score = validation_curve(Ridge(),X_train_s,y_train,"alpha",param_range,scoring='r2')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:68: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_score)
print(test_score)
# for each values of lambda we are getting three values of r2
# because validation curve is running k fold vaildation behind
# Out:
# [[9.98038013e-01 9.98051226e-01 9.98204001e-01 9.98194624e-01
#   9.98244144e-01]
#  [9.98038013e-01 9.98051226e-01 9.98204001e-01 9.98194624e-01
#   9.98244144e-01]
#  [9.98038013e-01 9.98051226e-01 9.98204001e-01 9.98194624e-01
#   9.98244144e-01]
#  [9.98038013e-01 9.98051226e-01 9.98204001e-01 9.98194624e-01
#   9.98244144e-01]
#  [9.98038012e-01 9.98051225e-01 9.98204000e-01 9.98194624e-01
#   9.98244144e-01]
#  [9.98038012e-01 9.98051225e-01 9.98204000e-01 9.98194623e-01
#   9.98244143e-01]
#  [9.98038011e-01 9.98051224e-01 9.98203999e-01 9.98194622e-01
#   9.98244143e-01]
#  [9.98038010e-01 9.98051223e-01 9.98203998e-01 9.98194621e-01
#   9.98244142e-01]
#  [9.98038009e-01 9.98051221e-01 9.98203996e-01 9.98194620e-01
#   9.98244140e-01]
#  [9.98038006e-01 9.98051219e-01 9.98203993e-01 9.98194617e-01
#   9.98244137e-01]
#  [9.98038003e-01 9.98051214e-01 9.98203988e-01 9.98194613e-01
#   9.98244133e-01]
#  [9.98037997e-01 9.98051207e-01 9.98203981e-01 9.98194606e-01
# ...

# %%
# calculating mean score of three values
train_mean = np.mean(train_score, axis = 1)

# %%
train_mean
# Out:
# array([9.98146402e-01, 9.98146402e-01, 9.98146401e-01, 9.98146401e-01,
#        9.98146401e-01, 9.98146401e-01, 9.98146400e-01, 9.98146399e-01,
#        9.98146397e-01, 9.98146394e-01, 9.98146390e-01, 9.98146383e-01,
#        9.98146372e-01, 9.98146355e-01, 9.98146328e-01, 9.98146285e-01,
#        9.98146216e-01, 9.98146108e-01, 9.98145938e-01, 9.98145670e-01,
#        9.98145250e-01, 9.98144595e-01, 9.98143578e-01, 9.98142010e-01,
#        9.98139607e-01, 9.98135960e-01, 9.98130486e-01, 9.98122373e-01,
#        9.98110528e-01, 9.98093531e-01, 9.98069606e-01, 9.98036635e-01,
#        9.97992204e-01, 9.97933696e-01, 9.97858383e-01, 9.97763511e-01,
#        9.97646310e-01, 9.97503938e-01, 9.97333326e-01, 9.97130930e-01,
#        9.96892349e-01, 9.96611765e-01, 9.96281138e-01, 9.95889105e-01,
#        9.95419520e-01, 9.94849534e-01, 9.94147011e-01, 9.93266977e-01,
#        9.92146698e-01, 9.90698932e-01, 9.88802750e-01, 9.86291072e-01,
# ...

# %% [markdown]
# This are 100 r2 values for 100 lambdas

# %% [markdown]
# #### Similarly for test values

# %%
test_mean = np.mean(test_score, axis = 1)

# %%
test_mean
# Out:
# array([ 9.98056808e-01,  9.98056807e-01,  9.98056806e-01,  9.98056805e-01,
#         9.98056804e-01,  9.98056801e-01,  9.98056798e-01,  9.98056795e-01,
#         9.98056789e-01,  9.98056782e-01,  9.98056772e-01,  9.98056758e-01,
#         9.98056737e-01,  9.98056708e-01,  9.98056665e-01,  9.98056601e-01,
#         9.98056506e-01,  9.98056364e-01,  9.98056148e-01,  9.98055819e-01,
#         9.98055318e-01,  9.98054555e-01,  9.98053390e-01,  9.98051620e-01,
#         9.98048943e-01,  9.98044922e-01,  9.98038938e-01,  9.98030137e-01,
#         9.98017375e-01,  9.97999172e-01,  9.97973696e-01,  9.97938774e-01,
#         9.97891956e-01,  9.97830606e-01,  9.97752008e-01,  9.97653442e-01,
#         9.97532195e-01,  9.97385492e-01,  9.97210340e-01,  9.97003271e-01,
#         9.96759947e-01,  9.96474586e-01,  9.96139140e-01,  9.95742184e-01,
#         9.95267458e-01,  9.94691961e-01,  9.93983394e-01,  9.93096613e-01,
# ...

# %% [markdown]
# #### looking values which are having highest r2 values

# %% [markdown]
# #### we are only intrested in model which have the highest r2 values

# %%
max(test_mean)
# Out:
# 0.9980568081658132

# %% [markdown]
# #### 0.998084... is the highest r2 value for our model

# %% [markdown]
# #### plotting scatter plot along with lambda value for better understanding

# %% [markdown]
# #### our lambda value is in exponential form we are taking log value

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)

# %% [markdown]
# #### As we se as we are increasing our lambda r2 values slightly decreasing and after a point it starts decreasing upto 0 value and r2 value is at 0 at very high lambda value

# %% [markdown]
# #### As we calculated earlier the r2 value at max pt is 0.998084...

# %% [markdown]
# #### Finding location of max value at a plot

# %%
np.where(test_mean == max(test_mean))
# Out:
# (array([0], dtype=int64),)

# %% [markdown]
# #### As we see the location of that value is at 0th index

# %% [markdown]
# #### Finding lambda value of 0th index

# %%
param_range[0]
# Out:
# 0.01

# %% [markdown]
# #### this is the lambda value at which we are getting a maximum r2 value

# %% [raw]
# Fitting Ridge model

# %%
lm_r_best = Ridge(alpha = param_range[0])

# %% [markdown]
# #### Fitting ridge model

# %%
lm_r_best.fit(X_train_s,y_train)
# Out:
# Ridge(alpha=0.01)

# %% [markdown]
# #### now Finding r2 values on test  & train data

# %%
r2_score(y_test,lm_r_best.predict(X_test_s))
# Out:
# 0.9965708346199764

# %%
r2_score(y_train,lm_r_best.predict(X_train_s))
# Out:
# 0.9981373098182948

# %% [markdown]
# #### As we compare both r2 values there is litte minor difference

# %% [markdown]
# # Train - Test split (Regression)

# %%
from sklearn.model_selection import train_test_split

# %%
df.head()
# Out:
#    Business  Age   Salary  Base_pay     Bonus  Unit_Price    Volume  \
# 0         0   18  5089.00  2035.600  5.539104        3.77  21226600
# 1         0   19  5698.12  2279.248  5.652159        3.74  10462800
# 2         0   22  5896.65  2358.660  5.686407        3.89  18761000
# 3         1   21  6125.12  2450.048  5.724421        4.35  66130600
# 4         0   23  6245.00  2498.000  5.743804        4.34  26868200
#
#    openingbalance  closingbalance       low  ...  Gender_Male  Type_One year  \
# 0        1.321756        1.324419  1.294727  ...            0              0
# 1        1.348073        1.302913  1.294727  ...            0              0
# 2        1.442202        1.456287  1.313724  ...            1              0
# 3        1.449269        1.460938  1.342865  ...            0              0
# 4        1.566530        1.483875  1.406097  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %%
X = df.loc[:,df.columns!="Salary"]

# %%
X.head()
# Out:
#    Business  Age  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0         0   18  2035.600  5.539104        3.77  21226600        1.321756
# 1         0   19  2279.248  5.652159        3.74  10462800        1.348073
# 2         0   22  2358.660  5.686407        3.89  18761000        1.442202
# 3         1   21  2450.048  5.724421        4.35  66130600        1.449269
# 4         0   23  2498.000  5.743804        4.34  26868200        1.566530
#
#    closingbalance       low  Unit_Sales  ...  Gender_Male  Type_One year  \
# 0        1.324419  1.294727       18.25  ...            0              0
# 1        1.302913  1.294727       18.40  ...            0              0
# 2        1.456287  1.313724       18.70  ...            1              0
# 3        1.460938  1.342865       18.75  ...            0              0
# 4        1.483875  1.406097       18.80  ...            1              0
#
#    Type_Two year  Dependancies_Yes  Calls_Yes  Billing_Yes  Rating_Yes  \
# ...

# %%
y = df["Salary"]

# %%
y.head()
# Out:
# 0    5089.00
# 1    5698.12
# 2    5896.65
# 3    6125.12
# 4    6245.00
# Name: Salary, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=0)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (3500, 23) (1500, 23) (3500,) (1500,)

# %% [markdown]
# # Training Regression Tree

# %%
from sklearn import tree

# %%
regtree = tree.DecisionTreeRegressor(max_depth = 3)

# %% [raw]
# created a object regtree
# regtree is our variable name which stands for regression tree &
# tree.DecisionTreeRegressor is our function
# max_depth is no of layers in our tree

# %% [markdown]
# #### Fitting X train and y train in regtree

# %%
regtree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# #### now regtree regressor object is ready now we can use regtree to predict the value of y using X train X test variable

# %% [markdown]
# # Predict value using trained model

# %%
y_train_pred = regtree.predict(X_train)
y_test_pred = regtree.predict(X_test)

# %%
y_test_pred
# Out:
# array([ 58817.5638924 , 115904.27481236, 151171.16667746, ...,
#         78768.51960369, 103263.50757343,  91966.62820937])

# %%
y_train_pred
# Out:
# array([103263.50757343,  91966.62820937,  91966.62820937, ...,
#         91966.62820937, 103263.50757343, 103263.50757343])

# %% [markdown]
# #### as we see we are saving our predicted value in y_train_pred & y_test_pred for X_train - test dataset

# %% [markdown]
# #### using this predicted value for calculating the performance

# %% [markdown]
# # Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %% [raw]
# mean_squared_error this is the mean of square of our deviation of predicted values from actual values &
# r2_score this is the goodness of fit or model artist square it ranges between 0 to 1

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 22240635.97936091

# %% [markdown]
# #### the mean squared error on our test dataset is 2 houndred and twenty three million

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.9618853686347625

# %% [markdown]
# #### it means our model is performing great

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9642778775808108

# %% [markdown]
# # Plotting decision tree

# %% [markdown]
# #### creating a dot file then we need to convert this dot file into image then we use a image to create a graph

# %%
dot_data = tree.export_graphviz(regtree, out_file=None)

# %% [markdown]
# #### importing required libraries

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %% [raw]
# if X[9] >= 65.175 than it will follow False branch &
# if X[9] <= 65.175 than it will follow True branch

# %% [markdown]
# #### As we see there is avg value= 99453 of sample and total no of observation are 3500

# %% [markdown]
# #### At bottom you can see there are 8 leaf notes having average values of each notes

# %% [markdown]
# #### For Better understanding

# %%
regtree1 = tree.DecisionTreeRegressor(max_depth = 3)
regtree1.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree1, out_file=None,feature_names = X_train.columns, filled = True)
graph1 = pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %% [raw]
# if Unit_Sales >= 65.17 is less than it will follow False branch &
# if Unit_Sales <= 65.17 is Greater than it will follow True branch
# contains sample size of 3500 and average value = 99453.05

# %% [markdown]
# #### The colour are changing according to the collection values
# #### white color shows the less collection values(15516) and dark orange shows the high collection value(151171)

# %%
regtree2 = tree.DecisionTreeRegressor(min_samples_split = 500)
regtree2.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree2, out_file=None,feature_names = X_train.columns, filled = True)
graph2 = pydotplus.graph_from_dot_data(dot_data)
Image(graph2.create_png())

# %%
regtree3 = tree.DecisionTreeRegressor(min_samples_leaf = 300)
regtree3.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree3, out_file=None,feature_names = X_train.columns, filled = True)
graph3 = pydotplus.graph_from_dot_data(dot_data)
Image(graph3.create_png())

# %% [markdown]
# # Conclusion :

# %% [markdown]
# ## 1.  The conclusion that i drawn from the this project that how different features are affecting the salary component,  For better understanding of the project i created a various model to give the best output results.

# %% [markdown]
# ## 2.  Salary of a employee depends upon various factors but it's mainly based on the Age of person, Education , Months in company,  Salarys also depend upon Total_sales, Unit_Sales, Unit_Price its upon the sales of the company and performance of employee.

# %% [markdown]
# ## 3. For the better understanding of HR about the company where to focus on about the company i built a model which will help him to get better insights about the employees and sales of company

# %% [markdown]
# ## 4. The Linear regression model is best model which i selected for better use because its giving me more accurate values then comparing to other models which i created

# %% [markdown]
# ## 5. Based on Linear Regression Model i.e how Business, Base_pay, Age , Volume, Openingbalance, Closingbalange, Unit_sales,     Total_sales, Months, Education, calls & Billing are giving positive output as we are generating profits from this variables but we have to focus on unit_price for the improvement of company and to make more sales of product
